# %%
import pandas as pd
import numpy as np
from scipy import stats

# read the data

data = pd.read_csv('caschool.csv')

# %%
data.describe()
# Out:
#        Observation Number      dist_cod      enrl_tot     teachers  \
# count          420.000000    420.000000    420.000000   420.000000
# mean           210.500000  67472.809524   2628.792857   129.067376
# std            121.387808   3466.994655   3913.104985   187.912679
# min              1.000000  61382.000000     81.000000     4.850000
# 25%            105.750000  64307.750000    379.000000    19.662499
# 50%            210.500000  67760.500000    950.500000    48.564999
# 75%            315.250000  70419.000000   3008.000000   146.350002
# max            420.000000  75440.000000  27176.000000  1429.000000
#
#          calw_pct    meal_pct     computer     testscr    comp_stu  \
# count  420.000000  420.000000   420.000000  420.000000  420.000000
# mean    13.246042   44.705237   303.383333  654.156548    0.135927
# std     11.454821   27.123381   441.341298   19.053348    0.064956
# min      0.000000    0.000000     0.000000  605.550049    0.000000
# ...
