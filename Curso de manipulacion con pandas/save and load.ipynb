# %%
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Collecting pandas
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 5.0 MB/s
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.5 which is incompatible.
# Successfully installed pandas-1.3.5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/Colab Notebooks'
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks
# 'America sur cuadrant graph thesis.ipynb'
# 'Avaluo apartamento.ipynb'
# 'Avaluos apartamento.ipynb'
#  Avaluos.ipynb
# 'Avaluos Terreno corregido.ipynb'
# 'Avaluos terreno.ipynb'
# 'Calculos tesis.ipynb'
# 'Copy of data_triathlon-jvelezmagic.ipynb'
# 'Copy of DiegoLesmes_data_triathlon.ipynb'
# 'Copy of notebook_data_triathlon.ipynb'
# 'cuadrant graph thesis.ipynb'
# 'Cuadro de anova.ipynb'
# 'Cursos platzi'
# 'datos panel.ipynb'
#  db
# 'Graficos, correlacion y data tesis.ipynb'
# 'graficos idh pruebas.ipynb'
# 'Idh resuelto.ipynb'
# 'Importar base de datos.ipynb'
#  introduccion_colab-1_588af5c7-3d2e-425b-a09a-f8674c236a83.ipynb
#  introduccion_colab_live_07b0ed82-599e-45a5-a89a-cbcdb23943bb.ipynb
# 'Prueba de busquedas merge funcionando.ipynb'

# %%
'Hola {}'.format('Hola hoñla asd')
# Out:
# 'Hola Hola hoñla asd'

# %%
# !mkdir /content/drive/My\ Drive/Colab\ Notebooks/db
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/Colab Notebooks/db’: File exists

# %%
dir_pandas = '/content/drive/My Drive/Colab Notebooks/db/{}'.format('test.xls')
dir_pandas
# Out:
# '/content/drive/My Drive/Colab Notebooks/db/test.xls'

# %%
import pandas as pd
pd.__version__
import numpy as np

# %%
dict_data = {
    'edad' :     [ 10, 9, 13, 14, 12, 11, 12],
    'cm' : [ 115, 110, 130, 155, 125, 120, 125],
    'pais' :    [ 'co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch'],
    'genero' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'Q1' : [ 5, 10, 8, np.nan, 7, 8, 3],
    'Q2' : [ 7, 9, 9, 8, 8, 8, 9.]
}
dict_data
# Out:
# {'Q1': [5, 10, 8, nan, 7, 8, 3],
#  'Q2': [7, 9, 9, 8, 8, 8, 9.0],
#  'cm': [115, 110, 130, 155, 125, 120, 125],
#  'edad': [10, 9, 13, 14, 12, 11, 12],
#  'genero': ['M', 'F', 'F', 'M', 'M', 'M', 'F'],
#  'pais': ['co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch']}

# %%
df = pd.DataFrame(dict_data)
print(df)
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %%
dir_pandas = '/content/drive/My Drive/Colab Notebooks/db/{}'.format('test.csv')
dir_pandas
# Out:
# '/content/drive/My Drive/Colab Notebooks/db/test.csv'

# %%
# Lo use para el error CompressionOptions' from 'pandas._typing' (/usr/local/lib/python3.7/dist-packages/pandas/_typing.py)

# !pip uninstall pandas
# !pip install pandas==1.1.5
# Out:
# Found existing installation: pandas 1.3.5
# Uninstalling pandas-1.3.5:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/pandas-1.3.5.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/pandas/*
# Proceed (y/n)? y
#   Successfully uninstalled pandas-1.3.5
# Collecting pandas==1.1.5
#   Downloading pandas-1.1.5-cp37-cp37m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 7.7 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.1.5) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.1.5) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas==1.1.5) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.1.5) (1.15.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.1.5

# %%
df.to_csv(dir_pandas, index = False)

# %%
# !ls /content/drive/My\ Drive/Colab\ Notebooks/db
# Out:
# test.csv

# %%
df_read = pd.read_csv('/content/drive/My Drive/Colab Notebooks/db/test.csv', sep = '|')
print(df_read)
# Out:
#   edad,cm,pais,genero,Q1,Q2
# 0       10,115,co,M,5.0,7.0
# 1       9,110,mx,F,10.0,9.0
# 2       13,130,co,F,8.0,9.0
# 3          14,155,mx,M,,8.0
# 4       12,125,mx,M,7.0,8.0
# 5       11,120,ch,M,8.0,8.0
# 6       12,125,ch,F,3.0,9.0

# %%
df.to_csv(dir_pandas, sep = '|', index = False)

# %%
dir_pandas = '/content/drive/My Drive/Colab Notebooks/db/{}'
dir_pandas
# Out:
# '/content/drive/My Drive/Colab Notebooks/db/{}'

# %%
df.to_excel(dir_pandas.format('test.xlsx'), index=False, sheet_name='Hoja_uno')

# %%
dir_pandas.format('test.xlsx')
# Out:
# '/content/drive/My Drive/Colab Notebooks/db/test.xlsx'

# %%
pd.read_excel(dir_pandas.format('test.xlsx'))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
df.to_json(dir_pandas.format('test.json'))

# %%
pd.read_json(dir_pandas.format('test.json'))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
df.to_pickle(dir_pandas.format('test.pkl'))

# %%
pd.read_pickle(dir_pandas.format('test.pkl'))
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %%
df.to_parquet(dir_pandas.format('test.parquet'))

# %%
df.to_hdf(dir_pandas.format('test.hdf'),key='data',format='table')

# %%
pd.read_parquet(dir_pandas.format('test.parquet'))
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %%
pd.read_hdf(dir_pandas.format('test.hdf'))
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0
