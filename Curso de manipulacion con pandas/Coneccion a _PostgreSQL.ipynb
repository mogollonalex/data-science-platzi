# %%
# !pip install psycopg2

# %%
import pandas as pd
import psycopg2
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
conn_sql = psycopg2.connect(user = "tcslzidebovfti",
                            password = "962c34e99a5232e5ef8d28d577bdf0a2f3b3ddceddab80418c01c795aae281bd",
                            host = "ec2-3-217-219-146.compute-1.amazonaws.com",
                            port = "5432",
                            database = "dgnsdh44cbsge")

# %%
query_sql = '''
select *
from app_clientes
limit 20
'''

# %%
df = pd.read_sql(query_sql, conn_sql)
df.head(5)
# Out:
#      id    nombre  apellido  ...                          updated imagen  fact
# 0  1096     RUBEN    BRACHO  ... 2021-04-29 12:55:27.432976+00:00         None
# 1  1100   LUZDARY    ANGULO  ... 2021-04-30 14:55:33.596277+00:00         None
# 2  1105     ANGEL   DUGARTE  ... 2020-11-04 01:36:15.510325+00:00         None
# 3     1  FERNANDO    TORRES  ... 2020-11-04 01:36:15.510325+00:00
# 4     2    SERGIO  GRISALES  ... 2020-11-04 22:16:49.507620+00:00
#
# [5 rows x 19 columns]
